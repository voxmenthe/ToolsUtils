# %%
import numpy as np

# %%
# !ls /workspace/mnt/crucial_2TB/111_Extra_Data/Macys
# Out:
# imgs224_1000  xtrain3150_260260.csv  xtrainonly1000.csv

# %%
data_dir = '/workspace/mnt/crucial_2TB/111_Extra_Data/Macys/'

# %%
xtrain3150_260260 = np.loadtxt(data_dir + 'xtrain3150_260260.csv', delimiter=',')

# %%
xtrain3150_260260.shape
# Out:
# (3150, 202800)

# %%
xtrain3150_260260[0].shape
# Out:
# (202800,)

# %%
sample = xtrain3150_260260[0].reshape(260,260,3)

# %%
sample.shape
# Out:
# (260, 260, 3)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
plt.imshow(sample)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
save_path = '/workspace/mnt/crucial_2TB/111_Extra_Data/Macys/imgs260_3150/'

# %%
matplotlib.image.imsave(save_path + 'sample.png', sample)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
for i in range(len(xtrain3150_260260)):
    image_name = save_path + 'img_' + str(i)
    matplotlib.image.imsave(image_name, xtrain3150_260260[i].reshape(260,260,3))
