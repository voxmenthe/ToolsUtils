# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img_path = '/home/jovyan/vmldata/raw_source_data/v20180810_all_wearables/7/2/723739_1342692.jpg'

# %%
test = Image.open(img_path)

# %%
plt.imshow(test)

# %%
np_from_Image = np.array(test)

# %%
np_from_Image.shape
# Out:
# (261, 214)

# %%
np_from_file = np.fromfile(img_path, dtype=np.uint8)

# %%
np_from_file.shape
# Out:
# (57740,)

# %%
261*214
# Out:
# 55854

# %%
261*214*3
# Out:
# 167562

# %%
import cv2
cv2im = cv2.imread(img_path)

# %%
cv2im.shape
# Out:
# (261, 214, 3)
